// %%
interp.load.ivy(("skac", "funnodes_2.12", "0.0.1-SNAPSHOT"))
// Out:
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.6/scala-library-2.12.6.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/1.2.0/cats-kernel_2.12-1.2.0.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.2.0/cats-core_2.12-1.2.0.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.12.4/scala-reflect-2.12.4.jar
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (23.58 %, 74225…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (19.32 %, 69310…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (18.09 %, 75864…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (17.21 %, 90663…
//
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (25.24 %, 79458…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (21.45 %, 76950…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (19.13 %, 80227…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (18.66 %, 98304…
//
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (28.34 %, 89212…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (24.19 %, 86781…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (21.15 %, 11141…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (21.09 %, 88419…
//
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (37.19 %, 11706…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (32.41 %, 11627…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (26.75 %, 14090…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (26.17 %, 10971…
//
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (41.87 %, 13181…
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (41.08 %, 14740…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (32.04 %, 16875…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (32.03 %, 13429…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (52.96 %, 19000…
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (51.76 %, 16294…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (40.62 %, 17033…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (39.50 %, 20807…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (64.37 %, 23096…
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (62.17 %, 19570…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (49.22 %, 20638…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (47.28 %, 24903…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (74.88 %, 26864…
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (72.58 %, 22847…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (57.42 %, 24079…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (54.12 %, 28508…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (86.29 %, 30960…
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (84.55 %, 26615…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (66.80 %, 28011…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (62.21 %, 32768…
//
// https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.… (99.08 %, 35547…
// https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/… (97.05 %, 30548…
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (76.18 %, 31943…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (70.61 %, 37191…
//
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.12.4/scala-reflect-2.12.4.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.12/1.2.0/cats-kernel_2.12-1.2.0.jar
// https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.… (90.63 %, 38005…
// https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.… (82.74 %, 43581…
//
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.12/1.2.0/cats-core_2.12-1.2.0.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.12.6/scala-library-2.12.6.jar

// %%
case class C1(a: Int)
// Out:
// defined class C1

// %%
class C2(b: Int) extends C1(b*2)
// Out:
// defined class C2

// %%
val c2 = new C2(10)
println(c2.a)
// Out:
// 20
// c2: C2 = C1(20)

// %%
import cats._
import cats.Monad
import cats.data.Writer
// Out:
// import cats._
//
// import cats.Monad
//
// import cats.data.Writer

// %%
import scala.annotation.tailrec

object Example {
  type ExampleMonad[A] = cats.data.Writer[String, A] 
  
  implicit val exampleMonadInstance: Monad[ExampleMonad] = new Monad[ExampleMonad] {
    def pure[A](a: A): ExampleMonad[A] = Writer("", a)
    def flatMap[A, B](fa: ExampleMonad[A])(f: A => ExampleMonad[B]): ExampleMonad[B] = {
      val new_writer = f(fa.value)
      Writer(fa.written ++ new_writer.written, new_writer.value)
    }
    override def map[A, B](fa: ExampleMonad[A])(f: A => B): ExampleMonad[B] = Writer(fa.written, f(fa.value))
    @tailrec
    def tailRecM[A, B](a: A)(f: A => ExampleMonad[Either[A, B]]): ExampleMonad[B] = {
      val new_w = f(a)
      val either_val = new_w.value
      either_val match {
        case Right(v) => Writer(new_w.written, v)
        case Left(v) => tailRecM(v)(f)
      }
    }
  }

//   implicit val ensembleMonoidInstance: Monoid[Ensemble] = new Monoid[Ensemble] {
//     override def combine(ens1: Ensemble, ens2: Ensemble) = ens1 ++ ens2
//     override def empty = Seq.empty[PosGraphic]
//   }  
}
// Out:
// import scala.annotation.tailrec
//
//
// defined object Example

// %%
import Example._
import com.github.skac112.funnodes._
import com.github.skac112.funnodes.FunNode._
val n = QuickNode[ExampleMonad, Double, Double]((a: Double) => Writer(s"wynik = ${a*2}", a*2))
val s1 = SplitUntil(n, (a: Double) => (.6*a, .4*a, ((a: Double, b: Double) => a + b)), (a: Double) => a > 1)
// Out:
// Something unexpected went wrong =(
// java.lang.StackOverflowError
//   scala.reflect.internal.Symbols$Symbol.rawInfo(Symbols.scala:1594)
//   scala.reflect.internal.Symbols$Symbol.info(Symbols.scala:1531)
//   scala.reflect.internal.Types$TypeRef.initializedTypeParams(Types.scala:2262)
//   scala.reflect.internal.Types$TypeRef.typeParamsMatchArgs(Types.scala:2263)
//   scala.reflect.internal.Types$AliasTypeRef.dealias(Types.scala:1990)
//   scala.reflect.internal.Types$AliasTypeRef.dealias$(Types.scala:1990)
//   scala.reflect.internal.Types$AliasArgsTypeRef.dealias(Types.scala:2417)
//   scala.reflect.internal.Types$Type.dealiasWiden(Types.scala:536)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
// ...
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
//   scala.tools.nsc.transform.SpecializeTypes.specializedTypeVars(SpecializeTypes.scala:458)
